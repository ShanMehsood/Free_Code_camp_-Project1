# %%
# import pandas library
import pandas as pd

# %%
# now Read the  Dataset From local 
d = pd.read_csv('adult.data.csv')

# %%
d
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %% [markdown]
# # giving columns names

# %%
column_names=['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','salary']

# %%
d.columns = column_names

# %%
d
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df = d.copy()

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
#race_count
race_count = df['race'].value_counts()

# %%
print(f'Number of each race: {race_count}')
# Out:
# Number of each race: race
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: count, dtype: int64

# %%
# Calculate the average age of men
average_age_men = df[df['sex'] == 'Male']['age'].mean()

# Print the result
print(f'Average age of men: {average_age_men}')
# Out:
# Average age of men: nan

# %%
df['sex'] = df['sex'].str.strip().str.capitalize()

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
print(df.isnull().sum())
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
average_age_men = df[df['sex'] == 'Male']['age'].mean()
print(f'Average age of men: {average_age_men}')
# Out:
# Average age of men: 39.433567396392675

# %% [markdown]
# # percentage of people who have bachelor

# %%
num_bachelor = len(df[df["education"]=='Bachelors'])

# %%
df['education'] = df['education'].str.strip().str.capitalize()

# %%
num_bachelor
# Out:
# 5354

# %%
total_num= len(df)

# %%
total_num
# Out:
# 32560

# %%
percentage_bachelors = num_bachelor/total_num*100

# %%
print(f'percentage_bachelors: {percentage_bachelors}')
# Out:
# percentage_bachelors: 16.443488943488944

# %% [markdown]
# ## What percentage of people with advanced education (Bachelors, Masters, or Doctorate) make more than 50K?

# %%
higher_education = df[df['education'].isin(['Bachelors', 'Masters', 'Doctorate'])]

# %%
print(f'higher_education :{higher_education }')
# Out:
# higher_education :       age          workclass  fnlwgt  education  education-num  \
# 0       50   Self-emp-not-inc   83311  Bachelors             13
# 3       28            Private  338409  Bachelors             13
# 4       37            Private  284582    Masters             14
# 7       31            Private   45781    Masters             14
# 8       42            Private  159449  Bachelors             13
# ...    ...                ...     ...        ...            ...
# 32537   38            Private  139180  Bachelors             13
# 32538   71                  ?  287372  Doctorate             16
# 32543   31            Private  199655    Masters             14
# 32552   32            Private  116138    Masters             14
# 32553   53            Private  321865    Masters             14
#
#             marital-status        occupation    relationship  \
# 0       Married-civ-spouse   Exec-managerial         Husband
# ...

# %%
lower_education= df[~df['education'].isin(['Bachelors', 'Masters', 'Doctorate'])]

# %%
print(f'lower_education:{lower_education}')
# Out:
# lower_education:       age          workclass  fnlwgt     education  education-num  \
# 1       38            Private  215646       Hs-grad              9
# 2       53            Private  234721          11th              7
# 5       49            Private  160187           9th              5
# 6       52   Self-emp-not-inc  209642       Hs-grad              9
# 9       37            Private  280464  Some-college             10
# ...    ...                ...     ...           ...            ...
# 32555   27            Private  257302    Assoc-acdm             12
# 32556   40            Private  154374       Hs-grad              9
# 32557   58            Private  151910       Hs-grad              9
# 32558   22            Private  201490       Hs-grad              9
# 32559   52       Self-emp-inc  287927       Hs-grad              9
#
#                marital-status          occupation    relationship    race  \
# ...

# %% [markdown]
# ## percentage with salary >50

# %%
print(df['salary'].unique())
print(df['education'].unique())
# Out:
# ['<=50k' '>50k']
# ['Bachelors' 'Hs-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th'
#  '1st-4th' 'Preschool' '12th']

# %%
df['salary'] = df['salary'].str.strip().str.capitalize()
df['education'] = df['education'].str.strip().str.capitalize()

# %%
df
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       50   Self-emp-not-inc   83311   Bachelors             13
# 1       38            Private  215646     Hs-grad              9
# 2       53            Private  234721        11th              7
# 3       28            Private  338409   Bachelors             13
# 4       37            Private  284582     Masters             14
# ...    ...                ...     ...         ...            ...
# 32555   27            Private  257302  Assoc-acdm             12
# 32556   40            Private  154374     Hs-grad              9
# 32557   58            Private  151910     Hs-grad              9
# 32558   22            Private  201490     Hs-grad              9
# 32559   52       Self-emp-inc  287927     Hs-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32560 non-null  int64
#  1   workclass       32560 non-null  object
#  2   fnlwgt          32560 non-null  int64
#  3   education       32560 non-null  object
#  4   education-num   32560 non-null  int64
#  5   marital-status  32560 non-null  object
#  6   occupation      32560 non-null  object
#  7   relationship    32560 non-null  object
#  8   race            32560 non-null  object
#  9   sex             32560 non-null  object
#  10  capital-gain    32560 non-null  int64
#  11  capital-loss    32560 non-null  int64
#  12  hours-per-week  32560 non-null  int64
#  13  native-country  32560 non-null  object
#  14  salary          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
non_percentage_higher = len(higher_education[higher_education['salary'] == ">50k"])
print(f'Number of higher education individuals earning >50K: {non_percentage_higher}')
# Out:
# Number of higher education individuals earning >50K: 3486

# %%
higher_education_rich =round(non_percentage_higher/len(higher_education)*100,1)

# %%
print(f'higher_education_rich:{higher_education_rich}')
# Out:
# higher_education_rich:46.5

# %%
non_percentage_lower = len(lower_education[lower_education['salary'] == ">50k"])

# %%
lower_education_rich = round(non_percentage_lower/len (lower_education)*100,1)

# %%
print(f'lower_education_rich: {lower_education_rich}')
# Out:
# lower_education_rich: 17.4

# %% [markdown]
# ## What is the minimum number of hours a person works per week?

# %%
min_work_hours = df['hours-per-week'].min()

# %%
print(f'min_work_hours: {min_work_hours}')
# Out:
# min_work_hours: 1

# %%
num_min_workers = df[df['hours-per-week']==min_work_hours]

# %%
rich_percentage = round(len(num_min_workers[num_min_workers.salary =='>50k'])/ len(num_min_workers)*100,1)

# %%
print(f'rich_percentage : {rich_percentage}')
# Out:
# rich_percentage : 10.0

# %% [markdown]
# ## What country has the highest percentage of people that earn >50K and what is that percentage?

# %%
country_count =df['native-country'].value_counts()

# %%
country_rich_count = df[df['salary']=='>50k']['native-country'].value_counts()

# %%
highest_earning_country = (country_rich_count/country_count *100).idxmax

# %%
print(f'highest_earning_country :{highest_earning_country}')
# Out:
# highest_earning_country :<bound method Series.idxmax of native-country
#  ?                             25.042882
#  Cambodia                      36.842105
#  Canada                        32.231405
#  China                         26.666667
#  Columbia                       3.389831
#  Cuba                          26.315789
#  Dominican-Republic             2.857143
#  Ecuador                       14.285714
#  El-Salvador                    8.490566
#  England                       33.333333
#  France                        41.379310
#  Germany                       32.116788
#  Greece                        27.586207
#  Guatemala                      4.687500
#  Haiti                          9.090909
#  Holand-Netherlands                  NaN
#  Honduras                       7.692308
#  Hong                          30.000000
#  Hungary                       23.076923
#  India                         40.000000
#  Iran                          41.860465
# ...

# %%
highest_earning_country = round((country_rich_count/country_count *100).max() ,1)

# %%
print(f'highest_earning_country:{highest_earning_country}')
# Out:
# highest_earning_country:41.9

# %% [markdown]
# ## Identify the most popular occupation for those who earn >50K in India

# %%
people_of_india = df[(df['native-country']=="India") & (df['salary']=='>50k')]

# %%
people_of_india
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
occupation_counts=  people_of_india['occupation'].value_counts()

# %%
print(f'occupation_counts :{occupation_counts}')
# Out:
# occupation_counts :Series([], Name: count, dtype: int64)

# %%
top_India_occupation= occupation_counts.idxmax()
